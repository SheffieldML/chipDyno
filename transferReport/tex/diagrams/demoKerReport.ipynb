# %%
import GPy
import numpy as np
import pylab as pb
pb.ion()
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /home/muhammad/mlprojects/GPy/GPy/util/linalg.py:44: UserWarning: warning: caught this exception:'module' object has no attribute '_dotblas'
#   warnings.warn("warning: caught this exception:" + str(e))

# %%
ker1 = GPy.kern.RBF(1)
ker2 = GPy.kern.RBF(input_dim=1, variance = 0.75, lengthscale=2.)
ker3 = GPy.kern.RBF(input_dim=1, variance = 0.5, lengthscale=0.5)

# %%
X = np.linspace(-5,5,11)[:,None]
Y = 0.5*X + 2*np.sin(X)
m = GPy.models.GPRegression(X,Y,ker1)

# %%
ker1 = GPy.kern.RBF(1)
ker2 = GPy.kern.RBF(input_dim=1, variance = 0.75, lengthscale=2.)
ker3 = GPy.kern.RBF(input_dim=1, variance = 0.5, lengthscale=0.5)
ker1.plot()
ker2.plot()
ker3.plot()

# %%
savefig("/home/muhammad/Dropbox/transferReport/tex/diagrams/SE_cov.eps")
#plt.show()

# %%
ker4 = GPy.kern.Cosine(input_dim=1, variance = 1.7, lengthscale=0.3)
ker5 = GPy.kern.Cosine(input_dim=1, variance = 0.5, lengthscale=0.5)
ker6 = GPy.kern.Cosine(input_dim=1, variance = 0.75, lengthscale=1.2)
ker4.plot()
ker5.plot()
ker6.plot()

# %%
#plt.savefig("/home/muhammad/Dropbox/transferReport/tex/diagrams/Cos_cov.pdf")

# %%
ker4 = GPy.kern.Matern32(input_dim=1, variance = 1.7, lengthscale=0.3)
ker5 = GPy.kern.Matern32(input_dim=1, variance = 0.5, lengthscale=0.5)
ker6 = GPy.kern.Matern32(input_dim=1, variance = 0.75, lengthscale=1.2)
ker4.plot()
ker5.plot()
ker6.plot()

# %%
ker4 = GPy.kern.Matern52(input_dim=1, variance = 1.7, lengthscale=0.3)
ker5 = GPy.kern.Matern52(input_dim=1, variance = 0.5, lengthscale=0.5)
ker6 = GPy.kern.Matern52(input_dim=1, variance = 0.75, lengthscale=1.2)
ker4.plot()
ker5.plot()
ker6.plot()

# %%
ker4 = GPy.kern.OU(input_dim=1, variance = 1.7, lengthscale=0.3)
ker5 = GPy.kern.OU(input_dim=1, variance = 0.5, lengthscale=0.5)
ker6 = GPy.kern.OU(input_dim=1, variance = 0.75, lengthscale=1.2)
ker4.plot()
ker5.plot()
ker6.plot()

# %%
ker1 = GPy.kern.RBF(1)
ker2 = GPy.kern.RBF(input_dim=1, variance = 0.75, lengthscale=2.)
ker3 = GPy.kern.RBF(input_dim=1, variance = 0.5, lengthscale=0.5)
ker1.plot()
ker2.plot()
ker3.plot()

# %%
# sample inputs and outputs
X = np.random.uniform(-3.,3.,(50,2))
Y = np.sin(X[:,0:1]) * np.sin(X[:,1:2])+np.random.randn(50,1)*0.05

# define kernel
ker = GPy.kern.Matern32(2,ARD=True)

# create simple GP model
m = GPy.models.GPRegression(X,Y,ker)

# contrain all parameters to be positive
m.constrain_positive('')

# optimize and plot
m.optimize('tnc', max_f_eval = 1000)
m.plot()
print(m)
# Out:
#   GP_regression.           |       Value       |  Constraint  |  Prior  |  Tied to
#   Mat32.variance           |   0.590365995334  |     +ve      |         |
#   Mat32.lengthscale        |             (2,)  |     +ve      |         |
#   Gaussian_noise.variance  |  0.0305608668009  |     +ve      |         |

# %%
# define kernel
ker = GPy.kern.Matern52(2,ARD=True)

# create simple GP model
m = GPy.models.GPRegression(X,Y,ker)

# contrain all parameters to be positive
m.constrain_positive('')

# optimize and plot
m.optimize('tnc', max_f_eval = 1000)
m.plot()
print(m)
# Out:
#   GP_regression.           |      Value       |  Constraint  |  Prior  |  Tied to
#   Mat52.variance           |   5.82163885444  |     +ve      |         |
#   Mat52.lengthscale        |            (2,)  |     +ve      |         |
#   Gaussian_noise.variance  |  0.013872456204  |     +ve      |         |

# %%
# define kernel
ker = GPy.kern.Matern32(2,ARD=True)

# create simple GP model
m = GPy.models.GPRegression(X,Y,ker)

# contrain all parameters to be positive
m.constrain_positive('')

# optimize and plot
m.optimize('tnc', max_f_eval = 1000)
m.plot()
print(m)
# Out:
#   GP_regression.           |       Value       |  Constraint  |  Prior  |  Tied to
#   Mat32.variance           |   0.590365995334  |     +ve      |         |
#   Mat32.lengthscale        |             (2,)  |     +ve      |         |
#   Gaussian_noise.variance  |  0.0305608668009  |     +ve      |         |

# %%
ker = GPy.kern.Matern32(2,ARD=True)
#ker.plot()
print ker
# Out:
#   Mat32.       |  Value  |  Constraint  |  Prior  |  Tied to
#   variance     |    1.0  |     +ve      |         |
#   lengthscale  |   (2,)  |     +ve      |         |

# %%
X = np.linspace(1,5,11)[:,None]

# %%
X
# Out:
# array([[ 1. ],
#        [ 1.4],
#        [ 1.8],
#        [ 2.2],
#        [ 2.6],
#        [ 3. ],
#        [ 3.4],
#        [ 3.8],
#        [ 4.2],
#        [ 4.6],
#        [ 5. ]])

# %%
ker1 = GPy.kern.RBF(1)
ker2 = GPy.kern.RBF(input_dim=1, variance = 0.75, lengthscale=2.)
ker3 = GPy.kern.RBF(input_dim=1, variance = 0.5, lengthscale=0.5)
ker1.plot()
ker2.plot()
ker3.plot()

# %%
ker2 = GPy.kern.RBF(input_dim=1, variance = 0.75, lengthscale=2.)

# %%
X = np.random.uniform(-30.,30.,(7,1))
Y = np.cos(X) + np.random.randn(7,1)*0.05

# %%
kernel = GPy.kern.RBF(input_dim=1, variance=5., lengthscale=1.)
kernel = GPy.kern.Cosine(input_dim=1, variance=10., lengthscale=10.01)

# %%
m = GPy.models.GPRegression(X,Y,kernel)
print m
#m.optimize()
m.plot(samples=1)
# Out:
#   GP_regression.           |  Value  |  Constraint  |  Prior  |  Tied to
#   Cosine.variance          |   10.0  |     +ve      |         |
#   Cosine.lengthscale       |  10.01  |     +ve      |         |
#   Gaussian_noise.variance  |    1.0  |     +ve      |         |
# {'dataplot': [<matplotlib.lines.Line2D at 0xdedbd10>],
#  'gpplot': [[<matplotlib.lines.Line2D at 0xded7a50>],
#   [<matplotlib.patches.Polygon at 0xded7f50>],
#   [<matplotlib.lines.Line2D at 0xdbf1090>],
#   [<matplotlib.lines.Line2D at 0xdedb810>]],
#  'posterior_samples': [<matplotlib.lines.Line2D at 0xdede210>]}

# %%
kernel.plot(samples=5)

# %%
X = np.array([1,3,7])[:,None]
Y = np.array([2,5,3])[:,None]

# %%
Y
# Out:
# array([[2],
#        [5],
#        [3]])

# %%
kernel = GPy.kern.RBF(input_dim=1, variance=5., lengthscale=.5)
m = GPy.models.GPRegression(X,Y,kernel)
print m
#m.optimize()
m.plot(samples=2)
# Out:
#   GP_regression.           |  Value  |  Constraint  |  Prior  |  Tied to
#   rbf.variance             |    5.0  |     +ve      |         |
#   rbf.lengthscale          |    0.5  |     +ve      |         |
#   Gaussian_noise.variance  |    1.0  |     +ve      |         |
# {'dataplot': [<matplotlib.lines.Line2D at 0xf3b7b90>],
#  'gpplot': [[<matplotlib.lines.Line2D at 0xf3b58d0>],
#   [<matplotlib.patches.Polygon at 0xf3b5cd0>],
#   [<matplotlib.lines.Line2D at 0xf3b5f50>],
#   [<matplotlib.lines.Line2D at 0xf3b7690>]],
#  'posterior_samples': [<matplotlib.lines.Line2D at 0xf3bb5d0>]}

# %%
kernel = GPy.kern.RBF(input_dim=1, variance=1., lengthscale=.8)
m = GPy.models.GPRegression(X,Y,kernel)
print m
#m.optimize()
m.plot(samples=1, fillcol='red')
# Out:
#   GP_regression.           |  Value  |  Constraint  |  Prior  |  Tied to
#   rbf.variance             |    1.0  |     +ve      |         |
#   rbf.lengthscale          |    0.8  |     +ve      |         |
#   Gaussian_noise.variance  |    1.0  |     +ve      |         |
# {'dataplot': [<matplotlib.lines.Line2D at 0x12d67790>],
#  'gpplot': [[<matplotlib.lines.Line2D at 0x12d634d0>],
#   [<matplotlib.patches.Polygon at 0x12d63750>],
#   [<matplotlib.lines.Line2D at 0x1209ea90>],
#   [<matplotlib.lines.Line2D at 0x12d67290>]],
#  'posterior_samples': [<matplotlib.lines.Line2D at 0x12d67c50>]}

# %%
X = np.array([1,3,17,50])[:,None]
Y = np.array([2,5,30,7])[:,None]
kernel = GPy.kern.RBF(input_dim=1, variance=10., lengthscale=5.0)
m = GPy.models.GPRegression(X,Y,kernel)
print m
#m.optimize()
m.plot(samples=1, fillcol='red')
# Out:
#   GP_regression.           |  Value  |  Constraint  |  Prior  |  Tied to
#   rbf.variance             |   10.0  |     +ve      |         |
#   rbf.lengthscale          |    5.0  |     +ve      |         |
#   Gaussian_noise.variance  |    1.0  |     +ve      |         |
# {'dataplot': [<matplotlib.lines.Line2D at 0x15ad9410>],
#  'gpplot': [[<matplotlib.lines.Line2D at 0x15ad6110>],
#   [<matplotlib.patches.Polygon at 0x15ad6610>],
#   [<matplotlib.lines.Line2D at 0x15ad6790>],
#   [<matplotlib.lines.Line2D at 0x15ad6ed0>]],
#  'posterior_samples': [<matplotlib.lines.Line2D at 0x15ad9c10>]}

# %%
X = np.array([1,3,17,50])[:,None]
Y = np.array([2,5,30,7])[:,None]
kernel = GPy.kern.RBF(input_dim=1, variance=1., lengthscale=1.0)
m = GPy.models.GPRegression(X,Y,kernel)
print m
#m.optimize()
m.plot(samples=1, fillcol='red')
# Out:
#   GP_regression.           |  Value  |  Constraint  |  Prior  |  Tied to
#   rbf.variance             |    1.0  |     +ve      |         |
#   rbf.lengthscale          |    1.0  |     +ve      |         |
#   Gaussian_noise.variance  |    1.0  |     +ve      |         |
# {'dataplot': [<matplotlib.lines.Line2D at 0x15d94310>],
#  'gpplot': [[<matplotlib.lines.Line2D at 0x15d91050>],
#   [<matplotlib.patches.Polygon at 0x15d91550>],
#   [<matplotlib.lines.Line2D at 0x1594d190>],
#   [<matplotlib.lines.Line2D at 0x15d91dd0>]],
#  'posterior_samples': [<matplotlib.lines.Line2D at 0x15d8cfd0>]}

# %%
X = np.array([1,3,17,50])[:,None]
Y = np.array([2,5,30,7])[:,None]
kernel = GPy.kern.RBF(input_dim=1, variance=10., lengthscale=5.0)
m = GPy.models.GPRegression(X,Y,kernel)
print m
#m.optimize()
m.plot(samples=1, fillcol='red')
# Out:
#   GP_regression.           |  Value  |  Constraint  |  Prior  |  Tied to
#   rbf.variance             |   10.0  |     +ve      |         |
#   rbf.lengthscale          |    5.0  |     +ve      |         |
#   Gaussian_noise.variance  |    1.0  |     +ve      |         |
# {'dataplot': [<matplotlib.lines.Line2D at 0x1686a8d0>],
#  'gpplot': [[<matplotlib.lines.Line2D at 0x16867610>],
#   [<matplotlib.patches.Polygon at 0x16867b10>],
#   [<matplotlib.lines.Line2D at 0x13aa0e10>],
#   [<matplotlib.lines.Line2D at 0x1686a3d0>]],
#  'posterior_samples': [<matplotlib.lines.Line2D at 0x1686ad90>]}

# %%
k1 = GPy.kern.RBF(1,.1,1)
#k2 = GPy.kern.periodic_Matern52(1,variance=1e3, lengthscale=1, period = 1.5, lower=-5., upper = 5)

#k = k1 * k2  # equivalent to k = k1.prod(k2)
#print k

# Simulate sample paths
X = np.linspace(0,10,501)[:,None]
Y = np.random.multivariate_normal(np.zeros(501),k1.K(X),1)
plt.plot(X,Y[0,:])

# %%
k1 = GPy.kern.RBF(1,.1,1)
#k2 = GPy.kern.periodic_Matern52(1,variance=1e3, lengthscale=1, period = 1.5, lower=-5., upper = 5)

#k = k1 * k2  # equivalent to k = k1.prod(k2)
#print k

# Simulate sample paths
X = np.linspace(-10,10,101)[:,None]
Y = np.random.multivariate_normal(np.zeros(101),k1.K(X),1)
plt.plot(X,Y[0,:])
Y = np.random.multivariate_normal(np.zeros(101),k1.K(X),1)
plt.plot(X,Y[0,:])
Y = np.random.multivariate_normal(np.zeros(101),k1.K(X),1)
plt.plot(X,Y[0,:])

# %%
#k1 = GPy.kern.RBF(1,.1,1)
k1 = GPy.kern.RBF(1,variance=.1, lengthscale=1.)
#k1 = GPy.kern.Matern52(1,variance=1e3, lengthscale=1, period = 1.5, lower=-5., upper = 5)

#k = k1 * k2  # equivalent to k = k1.prod(k2)
#print k

# Simulate sample paths
X = np.linspace(-10,10,101)[:,None]

#ax = plt.subplot(111)
Y = np.random.multivariate_normal(np.zeros(101),k1.K(X),1)
plt.plot(X,Y[0,:], label= 'Sample 1')
Y = np.random.multivariate_normal(np.zeros(101),k1.K(X),1)
plt.plot(X,Y[0,:], label= 'Sample 2')
Y = np.random.multivariate_normal(np.zeros(101),k1.K(X),1)
plt.plot(X,Y[0,:], label= 'Sample 3')

#ax.legend(loc='upper center', bbox_to_anchor=(0.5, 1.05),
#          ncol=1, fancybox=True, shadow=True)
legend(loc='upper center', bbox_to_anchor=(0.5, 1.05),
          ncol=3, fancybox=True, shadow=True)
plt.show()

# %%
plt.subplot(1, 4, 1)

ker1 = GPy.kern.RBF(1)
ker2 = GPy.kern.RBF(input_dim=1, variance = 0.75, lengthscale=2.)
ker3 = GPy.kern.RBF(input_dim=1, variance = 0.5, lengthscale=0.5)
ker1.plot()
ker2.plot()
ker3.plot()


plt.subplot(1, 4, 2-3)
#k1 = GPy.kern.RBF(1,.1,1)
k1 = GPy.kern.RBF(1,variance=.1, lengthscale=1.)
#k1 = GPy.kern.Matern52(1,variance=1e3, lengthscale=1, period = 1.5, lower=-5., upper = 5)

#k = k1 * k2  # equivalent to k = k1.prod(k2)
#print k

# Simulate sample paths
X = np.linspace(-10,10,101)[:,None]

#ax = plt.subplot(111)
Y = np.random.multivariate_normal(np.zeros(101),k1.K(X),1)
plt.plot(X,Y[0,:], label= 'Sample 1')
Y = np.random.multivariate_normal(np.zeros(101),k1.K(X),1)
plt.plot(X,Y[0,:], label= 'Sample 2')
Y = np.random.multivariate_normal(np.zeros(101),k1.K(X),1)
plt.plot(X,Y[0,:], label= 'Sample 3')

#ax.legend(loc='upper center', bbox_to_anchor=(0.5, 1.05),
#          ncol=1, fancybox=True, shadow=True)
legend(loc='upper center', bbox_to_anchor=(0.5, 1.05),
          ncol=3, fancybox=True, shadow=True)
plt.show()

# %%
ax1 = plt.subplot2grid((3,3), (0,0), colspan=3)
ax2 = plt.subplot2grid((3,3), (1,0), colspan=2)
ax3 = plt.subplot2grid((3,3), (1, 2), rowspan=2)
ax4 = plt.subplot2grid((3,3), (2, 0))
ax5 = plt.subplot2grid((3,3), (2, 1))

# %%
ax1 = plt.subplot2grid((3,3), (0,0), rowspan=3)
ax2 = plt.subplot2grid((3,3), (0,1), colspan=2, rowspan=3)

# %%
plt.subplot2grid((3,3), (1,0), rowspan=2)

ker1 = GPy.kern.RBF(input_dim=1, variance = .7, lengthscale=0.5)
ker2 = GPy.kern.RBF(input_dim=1, variance = 0.5, lengthscale=1.)
ker3 = GPy.kern.RBF(input_dim=1, variance = 0.2, lengthscale=2.)
ker1.plot()
ker2.plot()
ker3.plot()
plt.title('(a) Kernels')


plt.subplot2grid((3,3), (0,1), colspan=2, rowspan=3)
#k1 = GPy.kern.RBF(1,.1,1)
#k1 = GPy.kern.RBF(1,variance=.1, lengthscale=1.)

# Simulate sample paths
X = np.linspace(-10,10,501)[:,None]

#ax = plt.subplot(111)
Y = np.random.multivariate_normal(np.zeros(501),ker1.K(X),1)
plt.plot(X,Y[0,:], label= '$l=0.5; a=0.7$')
Y = np.random.multivariate_normal(np.zeros(501),ker2.K(X),1)
plt.plot(X,Y[0,:], label= '$l=1.0; a=0.5$')
Y = np.random.multivariate_normal(np.zeros(501),ker3.K(X),1)
plt.plot(X,Y[0,:], label= '$l=2.0; a=0.2$')
#plt.ylim([-1.2,1.2])
plt.title('(b) Sample functions')
#ax.legend(loc='upper center', bbox_to_anchor=(0.5, 1.05),
#          ncol=1, fancybox=True, shadow=True)

legend(loc='upper center', bbox_to_anchor=(-0.35, 1.05),
          ncol=1, fancybox=True, shadow=True)
plt.show()

# %%
savefig("/home/muhammad/Dropbox/transferReport/tex/diagrams/SE_cov.eps")

# %%
plt.subplot2grid((3,3), (1,0), rowspan=2)

ker1 = GPy.kern.RatQuad(input_dim=1, variance = .7, lengthscale=0.5)
ker2 = GPy.kern.RatQuad(input_dim=1, variance = 0.5, lengthscale=1.)
ker3 = GPy.kern.RatQuad(input_dim=1, variance = 0.2, lengthscale=2.)
ker1.plot()
ker2.plot()
ker3.plot()
plt.title('(a) Kernels')


plt.subplot2grid((3,3), (0,1), colspan=2, rowspan=3)
#k1 = GPy.kern.RBF(1,.1,1)
#k1 = GPy.kern.RBF(1,variance=.1, lengthscale=1.)

# Simulate sample paths
X = np.linspace(-10,10,501)[:,None]

#ax = plt.subplot(111)
Y = np.random.multivariate_normal(np.zeros(501),ker1.K(X),1)
plt.plot(X,Y[0,:], label= '$l=0.5; a=0.7$')
Y = np.random.multivariate_normal(np.zeros(501),ker2.K(X),1)
plt.plot(X,Y[0,:], label= '$l=1.0; a=0.5$')
Y = np.random.multivariate_normal(np.zeros(501),ker3.K(X),1)
plt.plot(X,Y[0,:], label= '$l=2.0; a=0.2$')
#plt.ylim([-1.2,1.2])
plt.title('(b) Sample functions')
#ax.legend(loc='upper center', bbox_to_anchor=(0.5, 1.05),
#          ncol=1, fancybox=True, shadow=True)

legend(loc='upper center', bbox_to_anchor=(-0.35, 1.05),
          ncol=1, fancybox=True, shadow=True)
plt.show()

# %%
plt.subplot2grid((3,3), (1,0), rowspan=2)

ker1 = GPy.kern.Matern32(input_dim=1, variance = .7, lengthscale=0.5)
ker2 = GPy.kern.Matern32(input_dim=1, variance = 0.5, lengthscale=1.)
ker3 = GPy.kern.Matern32(input_dim=1, variance = 0.2, lengthscale=2.)
ker1.plot()
ker2.plot()
ker3.plot()
plt.title('(a) Kernels')


plt.subplot2grid((3,3), (0,1), colspan=2, rowspan=3)
#k1 = GPy.kern.RBF(1,.1,1)
#k1 = GPy.kern.RBF(1,variance=.1, lengthscale=1.)

# Simulate sample paths
X = np.linspace(-10,10,501)[:,None]

#ax = plt.subplot(111)
Y = np.random.multivariate_normal(np.zeros(501),ker1.K(X),1)
plt.plot(X,Y[0,:], label= '$l=0.5; a=0.7$')
Y = np.random.multivariate_normal(np.zeros(501),ker2.K(X),1)
plt.plot(X,Y[0,:], label= '$l=1.0; a=0.5$')
Y = np.random.multivariate_normal(np.zeros(501),ker3.K(X),1)
plt.plot(X,Y[0,:], label= '$l=2.0; a=0.2$')
#plt.ylim([-1.2,1.2])
plt.title('(b) Sample functions')
#ax.legend(loc='upper center', bbox_to_anchor=(0.5, 1.05),
#          ncol=1, fancybox=True, shadow=True)

legend(loc='upper center', bbox_to_anchor=(-0.35, 1.05),
          ncol=1, fancybox=True, shadow=True)
plt.show()

# %%
plt.subplot2grid((3,3), (1,0), rowspan=2)

ker1 = GPy.kern.OU(input_dim=1, variance = .7, lengthscale=0.5)
ker2 = GPy.kern.OU(input_dim=1, variance = 0.5, lengthscale=1.)
ker3 = GPy.kern.OU(input_dim=1, variance = 0.2, lengthscale=2.)
ker1.plot()
ker2.plot()
ker3.plot()
plt.title('(a) Kernels')


plt.subplot2grid((3,3), (0,1), colspan=2, rowspan=3)
#k1 = GPy.kern.RBF(1,.1,1)
#k1 = GPy.kern.RBF(1,variance=.1, lengthscale=1.)

# Simulate sample paths
X = np.linspace(-10,10,501)[:,None]

#ax = plt.subplot(111)
Y = np.random.multivariate_normal(np.zeros(501),ker1.K(X),1)
plt.plot(X,Y[0,:], label= '$l=0.5; a=0.7$')
Y = np.random.multivariate_normal(np.zeros(501),ker2.K(X),1)
plt.plot(X,Y[0,:], label= '$l=1.0; a=0.5$')
Y = np.random.multivariate_normal(np.zeros(501),ker3.K(X),1)
plt.plot(X,Y[0,:], label= '$l=2.0; a=0.2$')
#plt.ylim([-1.2,1.2])
plt.title('(b) Sample functions')
#ax.legend(loc='upper center', bbox_to_anchor=(0.5, 1.05),
#          ncol=1, fancybox=True, shadow=True)

legend(loc='upper center', bbox_to_anchor=(-0.35, 1.05),
          ncol=1, fancybox=True, shadow=True)
plt.show()
