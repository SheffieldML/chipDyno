# %% [markdown]
# # Inferring Transcription Factor Activities by Combining Binding Information with Gene Expression Profiles

# %%
import numpy as np
import pylab as pb
import GPy
import scipy.io
import matplotlib.pyplot as plt

# %matplotlib inline
# Out:
# /home/muhammad/mlprojects/GPy/GPy/util/linalg.py:48: UserWarning: warning: caught this exception:'module' object has no attribute '_dotblas'
#   warnings.warn("warning: caught this exception:" + str(e))

# %%
data = GPy.util.datasets.spellman_yeast_cdc15()
Y = data['Y'].fillna(0) # Replace missing values with zero following Sanguinetti et al.
t = data['t']
#print data['info'], data['details']
#print Y

# %%
def plot_gene(gene_name='YBR265W'): # Test gene
#def plot_gene(gene_name='YER124C'): # Gene used in the paper
    plt.plot(data['t'], data['Y'][gene_name], 'rx')
    plt.title('Gene: ' + gene_name)
    plt.xlabel('time/minutes')
#plot_gene('YER124C')
plot_gene('YBR265W')

# %%
data = GPy.util.datasets.lee_yeast_ChIP()
# set S to find relationships where p-value is less than 1e-3
S = data['Y'].T<1e-3

# %%
intersect = list(set(S.columns) & set(Y.columns))
# this is the new value for n
print 'There are n=', len(intersect), 'overlapping genes.'
# Now reset S and Y to have the overlap of genes
Y = Y[intersect].T # now an n by T matrix
S = S[intersect].T # now an n by q matrix
Y.shape
#S.shape
# Out:
# There are n= 6099 overlapping genes.
# (6099, 23)

# %% [markdown]
# ### Model for Transcription Factor Activities

# %%
# step 1, find the SVD of S.
n, q = S.shape
T = Y.shape[1]
R, Lambda, V = np.linalg.svd(S)
# Extract first q columns for Q
Q = R[:, :q]
# remaining columns for U
U = R[:, q:]

# %%
Q.shape
U.shape
Y.shape
# Out:
# (6099, 23)

# %%
# Find sigma2 by looking at variance of y_u
Y_u = np.dot(U.T, Y)
sigma2 = 1./(T*(n-q))*(Y_u*Y_u).sum()
print "sigma2 found as", sigma2
# Out:
# sigma2 found as 0.178461463478

# %%
# Prepare the data for processing in GPy
Y_q = np.dot(Q.T, Y) # project data onto the principal subspace of X 

# Generate the input associated with each Y, the TF and the time point.
x0, x1 = np.asarray(np.meshgrid(t.flatten(),np.arange(q)))
X = np.hstack([x0.flatten()[:, None], x1.flatten()[:, None]])
y = Y_q.flatten()[:, None]

# %%
kern = GPy.kern.RBF(1, active_dims=[0])*GPy.kern.Coregionalize(1,q,rank=5, active_dims=[1])
#kern = GPy.kern.OU(1, active_dims=[0])*GPy.kern.Coregionalize(1,q,rank=5, active_dims=[1])
m = GPy.models.GPRegression(X, y, kern)
m.mul.rbf.lengthscale = 50
m.Gaussian_noise.variance = sigma2
#m.Gaussian_noise.variance.constrain_fixed()
#()#kern, t, y_q)
#m.sigma2 = constrained_fixed(sigma2)
#m.optimize(messages=True)

# %%
print m
# Out:
# Name                              : GP regression
# Log-likelihood                    : -3123.81696174
# Number of Parameters              : 681
# Number of Optimization Parameters : 681
# Updates                           : True
# Parameters:
#   GP_regression.           |      Value       |  Constraint  |  Prior  |  Tied to
#   mul.rbf.variance         |             1.0  |     +ve      |         |
#   mul.rbf.lengthscale      |            50.0  |     +ve      |         |
#   mul.coregion.W           |        (113, 5)  |              |         |
#   mul.coregion.kappa       |          (113,)  |     +ve      |         |
#   Gaussian_noise.variance  |  0.178461463478  |     +ve      |         |

# %%
m.optimize(messages=True)
# Out:
# Running L-BFGS-B (Scipy implementation) Code:
#  secs      i      f              |g|
#    0.23  0000   3.123817e+03           nan
#      18  0001   3.123817e+03   5.809076e+05
#      35  0002   2.877160e+03   1.961929e+04
#      51  0003   2.862002e+03   6.037775e+03
#
#      66  0004   2.852245e+03   5.145633e+03
#      81  0005   2.841251e+03   1.234454e+04
#      98  0006   2.770608e+03   2.286352e+05
#  1.1e+02  0007   2.698162e+03   1.114509e+05
#  1.3e+02  0008   2.550962e+03   2.706509e+04
#  1.4e+02  0009   2.450000e+03   1.969897e+04
#  1.6e+02  0010   2.314903e+03   3.128383e+04
#  1.7e+02  0011   2.314903e+03   3.128383e+04
#
# Optimization finished in 168.94 Seconds
# Optimization status: running
#
# KeyboardInterrupt caught, calling on_optimization_end() to round things up
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-9d08c21e823f> in <module>()
# ----> 1 m.optimize(messages=True)
#
# /home/muhammad/mlprojects/GPy/GPy/core/gp.pyc in optimize(self, optimizer, start, **kwargs)
#     440         self.inference_method.on_optimization_start()
#     441         try:
# --> 442             super(GP, self).optimize(optimizer, start, **kwargs)
#     443         except KeyboardInterrupt:
#     444             print "KeyboardInterrupt caught, calling on_optimization_end() to round things up"
#
# /home/muhammad/mlprojects/GPy/GPy/core/model.pyc in optimize(self, optimizer, start, messages, max_iters, ipython_notebook, clear_after_finish, **kwargs)
#     258
#     259         with VerboseOptimization(self, opt, maxiters=max_iters, verbose=messages, ipython_notebook=ipython_notebook) as vo:
# --> 260             opt.run(f_fp=self._objective_grads, f=self._objective, fp=self._grads)
#     261             vo.finish(opt)
#     262
#
# /home/muhammad/mlprojects/GPy/GPy/inference/optimization/optimization.pyc in run(self, **kwargs)
#      50     def run(self, **kwargs):
#      51         start = dt.datetime.now()
# ---> 52         self.opt(**kwargs)
#      53         end = dt.datetime.now()
#      54         self.time = str(end - start)
#
# /home/muhammad/mlprojects/GPy/GPy/inference/optimization/optimization.pyc in opt(self, f_fp, f, fp)
#     135
#     136         opt_result = optimize.fmin_l_bfgs_b(f_fp, self.x_init, iprint=iprint,
# --> 137                                             maxfun=self.max_iters, **opt_dict)
#     138         self.x_opt = opt_result[0]
#     139         self.f_opt = f_fp(self.x_opt)[0]
#
# /usr/local/lib/python2.7/dist-packages/scipy/optimize/lbfgsb.pyc in fmin_l_bfgs_b(func, x0, fprime, args, approx_grad, bounds, m, factr, pgtol, epsilon, iprint, maxfun, maxiter, disp, callback)
#     184
#     185     res = _minimize_lbfgsb(fun, x0, args=args, jac=jac, bounds=bounds,
# --> 186                            **opts)
#     187     d = {'grad': res['jac'],
#     188          'task': res['message'],
#
# /usr/local/lib/python2.7/dist-packages/scipy/optimize/lbfgsb.pyc in _minimize_lbfgsb(fun, x0, args, jac, bounds, disp, maxcor, ftol, gtol, eps, maxfun, maxiter, iprint, callback, **unknown_options)
#     312                 # minimization routine wants f and g at the current x
#     313                 # Overwrite f and g:
# --> 314                 f, g = func_and_grad(x)
#     315         elif task_str.startswith(b'NEW_X'):
#     316             # new iteration
#
# /usr/local/lib/python2.7/dist-packages/scipy/optimize/lbfgsb.pyc in func_and_grad(x)
#     263     else:
#     264         def func_and_grad(x):
# --> 265             f = fun(x, *args)
#     266             g = jac(x, *args)
#     267             return f, g
#
# /usr/local/lib/python2.7/dist-packages/scipy/optimize/optimize.pyc in function_wrapper(*wrapper_args)
#     279     def function_wrapper(*wrapper_args):
#     280         ncalls[0] += 1
# --> 281         return function(*(wrapper_args + args))
#     282
#     283     return ncalls, function_wrapper
#
# /usr/local/lib/python2.7/dist-packages/scipy/optimize/optimize.pyc in __call__(self, x, *args)
#      57     def __call__(self, x, *args):
#      58         self.x = numpy.asarray(x).copy()
# ---> 59         fg = self.fun(x, *args)
#      60         self.jac = fg[1]
#      61         return fg[0]
#
# /home/muhammad/mlprojects/GPy/GPy/core/model.pyc in _objective_grads(self, x)
#     203     def _objective_grads(self, x):
#     204         try:
# --> 205             self.optimizer_array = x
#     206             obj_f, self.obj_grads = self.objective_function(), self._transform_gradients(self.objective_function_gradients())
#     207             self._fail_count = 0
#
# /home/muhammad/mlprojects/GPy/GPy/core/parameterization/parameterized.pyc in __setattr__(self, name, val)
#     313             except AttributeError:
#     314                 pass
# --> 315         object.__setattr__(self, name, val);
#     316
#     317     #===========================================================================
#
# /home/muhammad/mlprojects/GPy/GPy/core/parameterization/parameter_core.pyc in optimizer_array(self, p)
#     650
#     651         self._optimizer_copy_transformed = False
# --> 652         self.trigger_update()
#     653
#     654     def _get_params_transformed(self):
#
# /home/muhammad/mlprojects/GPy/GPy/core/parameterization/updateable.pyc in trigger_update(self, trigger_parent)
#      52             #print "Warning: updates are off, updating the model will do nothing"
#      53             return
# ---> 54         self._trigger_params_changed(trigger_parent)
#
# /home/muhammad/mlprojects/GPy/GPy/core/parameterization/parameter_core.pyc in _trigger_params_changed(self, trigger_parent)
#     666         """
#     667         [p._trigger_params_changed(trigger_parent=False) for p in self.parameters if not p.is_fixed]
# --> 668         self.notify_observers(None, None if trigger_parent else -np.inf)
#     669
#     670     def _size_transformed(self):
#
# /home/muhammad/mlprojects/GPy/GPy/core/parameterization/observable.pyc in notify_observers(self, which, min_priority)
#      60                 which = self
#      61             if min_priority is None:
# ---> 62                 [callble(self, which=which) for _, _, callble in self.observers]
#      63             else:
#      64                 for p, _, callble in self.observers:
#
# /home/muhammad/mlprojects/GPy/GPy/core/parameterization/parameter_core.pyc in _parameters_changed_notification(self, me, which)
#     990         """
#     991         self._optimizer_copy_transformed = False # tells the optimizer array to update on next request
# --> 992         self.parameters_changed()
#     993     def _pass_through_notify_observers(self, me, which=None):
#     994         self.notify_observers(which=which)
#
# /home/muhammad/mlprojects/GPy/GPy/core/gp.pyc in parameters_changed(self)
#     154             this method yourself, there may be unexpected consequences.
#     155         """
# --> 156         self.posterior, self._log_marginal_likelihood, self.grad_dict = self.inference_method.inference(self.kern, self.X, self.likelihood, self.Y_normalized, self.Y_metadata)
#     157         self.likelihood.update_gradients(self.grad_dict['dL_dthetaL'])
#     158         self.kern.update_gradients_full(self.grad_dict['dL_dK'], self.X)
#
# /home/muhammad/mlprojects/GPy/GPy/inference/latent_function_inference/exact_gaussian_inference.pyc in inference(self, kern, X, likelihood, Y, Y_metadata)
#      47         Ky = K.copy()
#      48         diag.add(Ky, likelihood.gaussian_variance(Y_metadata))
# ---> 49         Wi, LW, LWi, W_logdet = pdinv(Ky)
#      50
#      51         alpha, _ = dpotrs(LW, YYT_factor, lower=1)
#
# /home/muhammad/mlprojects/GPy/GPy/util/linalg.pyc in pdinv(A, *args)
#     237     L = jitchol(A, *args)
#     238     logdet = 2.*np.sum(np.log(np.diag(L)))
# --> 239     Li = dtrtri(L)
#     240     Ai, _ = dpotri(L, lower=1)
#     241     # Ai = np.tril(Ai) + np.tril(Ai,-1).T
#
# /home/muhammad/mlprojects/GPy/GPy/util/linalg.pyc in dtrtri(L)
#     255
#     256     L = force_F_ordered(L)
# --> 257     return lapack.dtrtri(L, lower=1)[0]
#     258
#     259
#
# KeyboardInterrupt:

# %%
m.plot(fixed_inputs=[(1, 1)]) # this would plot ACE2.
print m
# Out:
#   GP_regression.           |        Value        |  Constraint  |  Prior  |  Tied to
#   mul.rbf.variance         |  0.000639099558844  |     +ve      |         |
#   mul.rbf.lengthscale      |       15.697544166  |     +ve      |         |
#   mul.coregion.W           |           (113, 5)  |              |         |
#   mul.coregion.kappa       |             (113,)  |     +ve      |         |
#   Gaussian_noise.variance  |      0.18903215637  |     +ve      |         |

# %%
m.plot(fixed_inputs=[(1, 1)]) # this would plot ACE2.
#pb.savefig('/home/muhammad/Desktop/test.png')
print m
# Out:
#   GP_regression.           |       Value       |  Constraint  |  Prior  |  Tied to
#   mul.rbf.variance         |  0.0277005887048  |     +ve      |         |
#   mul.rbf.lengthscale      |    47.9752810026  |     +ve      |         |
#   mul.coregion.W           |         (113, 5)  |              |         |
#   mul.coregion.kappa       |           (113,)  |     +ve      |         |
#   Gaussian_noise.variance  |   0.320768775315  |     +ve      |         |
