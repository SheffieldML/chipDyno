# %%
import GPy
import numpy as np
import pylab as pb
import matplotlib.pyplot as plt
pb.ion()
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /home/muhammad/mlprojects/GPy/GPy/util/linalg.py:44: UserWarning: warning: caught this exception:'module' object has no attribute '_dotblas'
#   warnings.warn("warning: caught this exception:" + str(e))

# %%
ker1 = GPy.kern.RBF(1)
ker2 = GPy.kern.RBF(input_dim=1, variance = 0.75, lengthscale=2.)
ker3 = GPy.kern.RBF(input_dim=1, variance = 0.5, lengthscale=0.5)

# %%
X = np.linspace(-10,10,11)[:,None]
Y = 0.5*X + 2*np.sin(X)
m = GPy.models.GPRegression(X,Y,ker1)

# %%
ker1 = GPy.kern.RBF(1)
ker2 = GPy.kern.RBF(input_dim=1, variance = 0.75, lengthscale=2.)
ker3 = GPy.kern.RBF(input_dim=1, variance = 0.5, lengthscale=0.5)
ker1.plot()
ker2.plot()
ker3.plot()

# %%
savefig("/home/muhammad/Dropbox/transferReport/tex/diagrams/SE_cov.eps")
#plt.show()

# %%
ker4 = GPy.kern.Cosine(input_dim=1, variance = 1.7, lengthscale=0.3)
ker5 = GPy.kern.Cosine(input_dim=1, variance = 0.5, lengthscale=0.5)
ker6 = GPy.kern.Cosine(input_dim=1, variance = 0.75, lengthscale=1.2)
ker4.plot()
ker5.plot()
ker6.plot()

# %%
#plt.savefig("/home/muhammad/Dropbox/transferReport/tex/diagrams/Cos_cov.pdf")

# %%
ker4 = GPy.kern.Matern32(input_dim=1, variance = 1.7, lengthscale=0.3)
ker5 = GPy.kern.Matern32(input_dim=1, variance = 0.5, lengthscale=0.5)
ker6 = GPy.kern.Matern32(input_dim=1, variance = 0.75, lengthscale=1.2)
ker4.plot()
ker5.plot()
ker6.plot()

# %%
ker4 = GPy.kern.Matern52(input_dim=1, variance = 1.7, lengthscale=0.3)
ker5 = GPy.kern.Matern52(input_dim=1, variance = 0.5, lengthscale=0.5)
ker6 = GPy.kern.Matern52(input_dim=1, variance = 0.75, lengthscale=1.2)
ker4.plot()
ker5.plot()
ker6.plot()

# %%
ker4 = GPy.kern.OU(input_dim=1, variance = 1.7, lengthscale=0.3)
ker5 = GPy.kern.OU(input_dim=1, variance = 0.5, lengthscale=0.5)
ker6 = GPy.kern.OU(input_dim=1, variance = 0.75, lengthscale=1.2)
ker4.plot()
ker5.plot()
ker6.plot()

# %%
ker1 = GPy.kern.RBF(1)
ker2 = GPy.kern.RBF(input_dim=1, variance = 0.75, lengthscale=2.)
ker3 = GPy.kern.RBF(input_dim=1, variance = 0.5, lengthscale=0.5)
ker1.plot()
ker2.plot()
ker3.plot()

# %%
# sample inputs and outputs
X = np.random.uniform(-3.,3.,(50,2))
Y = np.sin(X[:,0:1]) * np.sin(X[:,1:2])+np.random.randn(50,1)*0.05

# define kernel
ker = GPy.kern.Matern32(2,ARD=True)

# create simple GP model
m = GPy.models.GPRegression(X,Y,ker)

# contrain all parameters to be positive
m.constrain_positive('')

# optimize and plot
m.optimize('tnc', max_f_eval = 1000)
m.plot()
print(m)
# Out:
#   GP_regression.           |       Value        |  Constraint  |  Prior  |  Tied to
#   Mat32.variance           |   0.0905631930081  |     +ve      |         |
#   Mat32.lengthscale        |              (2,)  |     +ve      |         |
#   Gaussian_noise.variance  |  0.00236473433886  |     +ve      |         |

# %%
# define kernel
ker = GPy.kern.Matern52(2,ARD=True)

# create simple GP model
m = GPy.models.GPRegression(X,Y,ker)

# contrain all parameters to be positive
m.constrain_positive('')

# optimize and plot
m.optimize('tnc', max_f_eval = 1000)
m.plot()
print(m)
# Out:
#   GP_regression.           |       Value        |  Constraint  |  Prior  |  Tied to
#   Mat52.variance           |    0.260998396567  |     +ve      |         |
#   Mat52.lengthscale        |              (2,)  |     +ve      |         |
#   Gaussian_noise.variance  |  0.00233841191822  |     +ve      |         |

# %%
# define kernel
ker = GPy.kern.Matern32(2,ARD=True)

# create simple GP model
m = GPy.models.GPRegression(X,Y,ker)

# contrain all parameters to be positive
m.constrain_positive('')

# optimize and plot
m.optimize('tnc', max_f_eval = 1000)
m.plot()
print(m)
# Out:
#   GP_regression.           |       Value        |  Constraint  |  Prior  |  Tied to
#   Mat32.variance           |   0.0905631930081  |     +ve      |         |
#   Mat32.lengthscale        |              (2,)  |     +ve      |         |
#   Gaussian_noise.variance  |  0.00236473433886  |     +ve      |         |

# %%
ker = GPy.kern.Matern32(2,ARD=True)
#ker.plot()
print ker
# Out:
#   Mat32.       |  Value  |  Constraint  |  Prior  |  Tied to
#   variance     |    1.0  |     +ve      |         |
#   lengthscale  |   (2,)  |     +ve      |         |

# %%
X = np.linspace(1,5,11)[:,None]

# %%
ker1 = GPy.kern.RBF(1)
ker2 = GPy.kern.RBF(input_dim=1, variance = 0.75, lengthscale=2.)
ker3 = GPy.kern.RBF(input_dim=1, variance = 0.5, lengthscale=0.5)
ker1.plot()
ker2.plot()
ker3.plot()

# %%
ker2 = GPy.kern.RBF(input_dim=1, variance = 0.75, lengthscale=2.)

# %%
k1 = GPy.kern.RBF(1,.1,1)
#k2 = GPy.kern.periodic_Matern52(1,variance=1e3, lengthscale=1, period = 1.5, lower=-5., upper = 5)

#k = k1 * k2  # equivalent to k = k1.prod(k2)
#print k

# Simulate sample paths
X = np.linspace(0,10,501)[:,None]
Y = np.random.multivariate_normal(np.zeros(501),k1.K(X),1)
plt.plot(X,Y[0,:])

# %%
k1 = GPy.kern.RBF(1,.1,1)
#k2 = GPy.kern.periodic_Matern52(1,variance=1e3, lengthscale=1, period = 1.5, lower=-5., upper = 5)

#k = k1 * k2  # equivalent to k = k1.prod(k2)
#print k

# Simulate sample paths
X = np.linspace(-10,10,101)[:,None]
Y = np.random.multivariate_normal(np.zeros(101),k1.K(X),1)
plt.plot(X,Y[0,:])
Y = np.random.multivariate_normal(np.zeros(101),k1.K(X),1)
plt.plot(X,Y[0,:])
Y = np.random.multivariate_normal(np.zeros(101),k1.K(X),1)
plt.plot(X,Y[0,:])

# %%
#k1 = GPy.kern.RBF(1,.1,1)
k1 = GPy.kern.RBF(1,variance=.1, lengthscale=1.)
#k1 = GPy.kern.Matern52(1,variance=1e3, lengthscale=1, period = 1.5, lower=-5., upper = 5)

#k = k1 * k2  # equivalent to k = k1.prod(k2)
#print k

# Simulate sample paths
X = np.linspace(-10,10,101)[:,None]

#ax = plt.subplot(111)
Y = np.random.multivariate_normal(np.zeros(101),k1.K(X),1)
plt.plot(X,Y[0,:], label= 'Sample 1')
Y = np.random.multivariate_normal(np.zeros(101),k1.K(X),1)
plt.plot(X,Y[0,:], label= 'Sample 2')
Y = np.random.multivariate_normal(np.zeros(101),k1.K(X),1)
plt.plot(X,Y[0,:], label= 'Sample 3')

#ax.legend(loc='upper center', bbox_to_anchor=(0.5, 1.05),
#          ncol=1, fancybox=True, shadow=True)
legend(loc='upper center', bbox_to_anchor=(0.5, 1.05),
          ncol=3, fancybox=True, shadow=True)
plt.show()

# %%
ax1 = plt.subplot2grid((3,3), (0,0), colspan=3)
ax2 = plt.subplot2grid((3,3), (1,0), colspan=2)
ax3 = plt.subplot2grid((3,3), (1, 2), rowspan=2)
ax4 = plt.subplot2grid((3,3), (2, 0))
ax5 = plt.subplot2grid((3,3), (2, 1))

# %%
ax1 = plt.subplot2grid((3,3), (0,0), rowspan=3)
ax2 = plt.subplot2grid((3,3), (0,1), colspan=2, rowspan=3)

# %%
plt.subplot2grid((3,3), (1,0), rowspan=2)

ker1 = GPy.kern.RBF(input_dim=1, variance = .7, lengthscale=0.5)
ker2 = GPy.kern.RBF(input_dim=1, variance = 0.5, lengthscale=1.)
ker3 = GPy.kern.RBF(input_dim=1, variance = 0.2, lengthscale=2.)
ker1.plot()
ker2.plot()
ker3.plot()
plt.title('(a) Kernels')


plt.subplot2grid((3,3), (0,1), colspan=2, rowspan=3)
#k1 = GPy.kern.RBF(1,.1,1)
#k1 = GPy.kern.RBF(1,variance=.1, lengthscale=1.)

# Simulate sample paths
X = np.linspace(-10,10,501)[:,None]

#ax = plt.subplot(111)
Y = np.random.multivariate_normal(np.zeros(501),ker1.K(X),1)
plt.plot(X,Y[0,:], label= '$l=0.5; a=0.7$')
Y = np.random.multivariate_normal(np.zeros(501),ker2.K(X),1)
plt.plot(X,Y[0,:], label= '$l=1.0; a=0.5$')
Y = np.random.multivariate_normal(np.zeros(501),ker3.K(X),1)
plt.plot(X,Y[0,:], label= '$l=2.0; a=0.2$')
#plt.ylim([-1.2,1.2])
plt.title('(b) Sample functions')
#ax.legend(loc='upper center', bbox_to_anchor=(0.5, 1.05),
#          ncol=1, fancybox=True, shadow=True)

legend(loc='upper center', bbox_to_anchor=(-0.35, 1.05),
          ncol=1, fancybox=True, shadow=True)
plt.show()

# %%
#savefig("/home/muhammad/Dropbox/transferReport/tex/diagrams/SE_cov.eps")

# %%
plt.subplot2grid((3,3), (1,0), rowspan=2)

ker1 = GPy.kern.RatQuad(input_dim=1, variance = .7, lengthscale=0.5)
ker2 = GPy.kern.RatQuad(input_dim=1, variance = 0.5, lengthscale=1.)
ker3 = GPy.kern.RatQuad(input_dim=1, variance = 0.2, lengthscale=2.)
ker1.plot()
ker2.plot()
ker3.plot()
plt.title('(a) Kernels')


plt.subplot2grid((3,3), (0,1), colspan=2, rowspan=3)
#k1 = GPy.kern.RBF(1,.1,1)
#k1 = GPy.kern.RBF(1,variance=.1, lengthscale=1.)

# Simulate sample paths
X = np.linspace(-10,10,501)[:,None]

#ax = plt.subplot(111)
Y = np.random.multivariate_normal(np.zeros(501),ker1.K(X),1)
plt.plot(X,Y[0,:], label= '$l=0.5; a=0.7$')
Y = np.random.multivariate_normal(np.zeros(501),ker2.K(X),1)
plt.plot(X,Y[0,:], label= '$l=1.0; a=0.5$')
Y = np.random.multivariate_normal(np.zeros(501),ker3.K(X),1)
plt.plot(X,Y[0,:], label= '$l=2.0; a=0.2$')
#plt.ylim([-1.2,1.2])
plt.title('(b) Sample functions')
#ax.legend(loc='upper center', bbox_to_anchor=(0.5, 1.05),
#          ncol=1, fancybox=True, shadow=True)

legend(loc='upper center', bbox_to_anchor=(-0.35, 1.05),
          ncol=1, fancybox=True, shadow=True)
plt.show()

# %%
plt.subplot2grid((3,3), (1,0), rowspan=2)

ker1 = GPy.kern.Matern32(input_dim=1, variance = .7, lengthscale=0.5)
ker2 = GPy.kern.Matern32(input_dim=1, variance = 0.5, lengthscale=1.)
ker3 = GPy.kern.Matern32(input_dim=1, variance = 0.2, lengthscale=2.)
ker1.plot()
ker2.plot()
ker3.plot()
plt.title('(a) Kernels')


plt.subplot2grid((3,3), (0,1), colspan=2, rowspan=3)
#k1 = GPy.kern.RBF(1,.1,1)
#k1 = GPy.kern.RBF(1,variance=.1, lengthscale=1.)

# Simulate sample paths
X = np.linspace(-10,10,501)[:,None]

#ax = plt.subplot(111)
Y = np.random.multivariate_normal(np.zeros(501),ker1.K(X),1)
plt.plot(X,Y[0,:], label= '$l=0.5; a=0.7$')
Y = np.random.multivariate_normal(np.zeros(501),ker2.K(X),1)
plt.plot(X,Y[0,:], label= '$l=1.0; a=0.5$')
Y = np.random.multivariate_normal(np.zeros(501),ker3.K(X),1)
plt.plot(X,Y[0,:], label= '$l=2.0; a=0.2$')
#plt.ylim([-1.2,1.2])
plt.title('(b) Sample functions')
#ax.legend(loc='upper center', bbox_to_anchor=(0.5, 1.05),
#          ncol=1, fancybox=True, shadow=True)

legend(loc='upper center', bbox_to_anchor=(-0.35, 1.05),
          ncol=1, fancybox=True, shadow=True)
plt.show()

# %%
plt.subplot2grid((3,3), (1,0), rowspan=2)

ker1 = GPy.kern.OU(input_dim=1, variance = .7, lengthscale=0.5)
ker2 = GPy.kern.OU(input_dim=1, variance = 0.5, lengthscale=1.)
ker3 = GPy.kern.OU(input_dim=1, variance = 0.2, lengthscale=2.)
ker1.plot()
ker2.plot()
ker3.plot()
plt.title('(a) Kernels')


plt.subplot2grid((3,3), (0,1), colspan=2, rowspan=3)
#k1 = GPy.kern.RBF(1,.1,1)
#k1 = GPy.kern.RBF(1,variance=.1, lengthscale=1.)

# Simulate sample paths
X = np.linspace(-10,10,501)[:,None]

#ax = plt.subplot(111)
Y = np.random.multivariate_normal(np.zeros(501),ker1.K(X),1)
plt.plot(X,Y[0,:], label= '$l=0.5; a=0.7$')
Y = np.random.multivariate_normal(np.zeros(501),ker2.K(X),1)
plt.plot(X,Y[0,:], label= '$l=1.0; a=0.5$')
Y = np.random.multivariate_normal(np.zeros(501),ker3.K(X),1)
plt.plot(X,Y[0,:], label= '$l=2.0; a=0.2$')
#plt.ylim([-1.2,1.2])
plt.title('(b) Sample functions')
#ax.legend(loc='upper center', bbox_to_anchor=(0.5, 1.05),
#          ncol=1, fancybox=True, shadow=True)

legend(loc='upper center', bbox_to_anchor=(-0.35, 1.05),
          ncol=1, fancybox=True, shadow=True)
plt.show()

# %%
plt.subplot2grid((3,3), (1,0), rowspan=2)

ker1 = GPy.kern.RatQuad(input_dim=1, variance = 0.5, lengthscale=0.5)
ker2 = GPy.kern.RatQuad(input_dim=1, variance = 1.0, lengthscale=1.0)
ker3 = GPy.kern.RatQuad(input_dim=1, variance = 2.0, lengthscale=2.0)
ker1.plot()
ker2.plot()
ker3.plot()
plt.title('(a) Kernels')


plt.subplot2grid((3,3), (0,1), colspan=2, rowspan=3)
#k1 = GPy.kern.RBF(1,.1,1)
#k1 = GPy.kern.RBF(1,variance=.1, lengthscale=1.)

# Simulate sample paths
X = np.linspace(-10,10,501)[:,None]

#ax = plt.subplot(111)
Y = np.random.multivariate_normal(np.zeros(501),ker1.K(X),1)
plt.plot(X,Y[0,:], label= '$l=0.5; a=0.5$')
Y = np.random.multivariate_normal(np.zeros(501),ker2.K(X),1)
plt.plot(X,Y[0,:], label= '$l=1.0; a=1.0$')
Y = np.random.multivariate_normal(np.zeros(501),ker3.K(X),1)
plt.plot(X,Y[0,:], label= '$l=2.0; a=2.0$')
#plt.ylim([-1.2,1.2])
plt.title('(b) Sample functions')
#ax.legend(loc='upper center', bbox_to_anchor=(0.5, 1.05),
#          ncol=1, fancybox=True, shadow=True)

legend(loc='upper center', bbox_to_anchor=(-0.35, 1.05),
          ncol=1, fancybox=True, shadow=True)
#plt.show()

#savefig("/home/muhammad/Dropbox/transferReport/tex/diagrams/RQ3_cov.eps")

# %%
plt.subplot2grid((3,3), (1,0), rowspan=2)

ker1 = GPy.kern.Matern32(input_dim=1, variance = .7, lengthscale=0.5)
ker2 = GPy.kern.Matern32(input_dim=1, variance = 0.5, lengthscale=2.)
ker3 = GPy.kern.Matern32(input_dim=1, variance = 0.2, lengthscale=1.)
ker1.plot()
ker2.plot()
ker3.plot()
plt.title('(a) Kernels')


plt.subplot2grid((3,3), (0,1), colspan=2, rowspan=3)
#k1 = GPy.kern.RBF(1,.1,1)
#k1 = GPy.kern.RBF(1,variance=.1, lengthscale=1.)

# Simulate sample paths
X = np.linspace(-10,10,501)[:,None]

#ax = plt.subplot(111)savefig("/home/muhammad/Dropbox/transferReport/tex/diagrams/Mat32_edit_cov.eps")
Y = np.random.multivariate_normal(np.zeros(501),ker1.K(X),1)
plt.plot(X,Y[0,:], label= '$l=0.5; a=0.7$')
Y = np.random.multivariate_normal(np.zeros(501),ker2.K(X),1)
plt.plot(X,Y[0,:], label= '$l=2.0; a=0.5$')
Y = np.random.multivariate_normal(np.zeros(501),ker3.K(X),1)
plt.plot(X,Y[0,:], label= '$l=1.0; a=0.2$')
#plt.ylim([-1.2,1.2])
plt.title('(b) Sample functions')
#ax.legend(loc='upper center', bbox_to_anchor=(0.5, 1.05),
#          ncol=1, fancybox=True, shadow=True)

legend(loc='upper center', bbox_to_anchor=(-0.35, 1.05),
          ncol=1, fancybox=True, shadow=True)
#plt.show()
#savefig("/home/muhammad/Dropbox/transferReport/tex/diagrams/Mat32_edit_cov.eps")

# %%
plt.subplot2grid((3,3), (1,0), rowspan=2)

ker1 = GPy.kern.Cosine(input_dim=1, variance = .7, lengthscale=0.5)
ker2 = GPy.kern.Cosine(input_dim=1, variance = 0.5, lengthscale=2.)
ker3 = GPy.kern.Cosine(input_dim=1, variance = 0.2, lengthscale=1.)
ker1.plot()
ker2.plot()
ker3.plot()
plt.title('(a) Kernels')


plt.subplot2grid((3,3), (0,1), colspan=2, rowspan=3)
#k1 = GPy.kern.RBF(1,.1,1)
#k1 = GPy.kern.RBF(1,variance=.1, lengthscale=1.)

# Simulate sample paths
X = np.linspace(-10,10,501)[:,None]

#ax = plt.subplot(111)savefig("/home/muhammad/Dropbox/transferReport/tex/diagrams/Mat32_edit_cov.eps")
Y = np.random.multivariate_normal(np.zeros(501),ker1.K(X),1)
plt.plot(X,Y[0,:], label= '$l=0.5; a=0.7$')
Y = np.random.multivariate_normal(np.zeros(501),ker2.K(X),1)
plt.plot(X,Y[0,:], label= '$l=2.0; a=0.5$')
Y = np.random.multivariate_normal(np.zeros(501),ker3.K(X),1)
plt.plot(X,Y[0,:], label= '$l=1.0; a=0.2$')
#plt.ylim([-1.2,1.2])
plt.title('(b) Sample functions')
#ax.legend(loc='upper center', bbox_to_anchor=(0.5, 1.05),
#          ncol=1, fancybox=True, shadow=True)

legend(loc='upper center', bbox_to_anchor=(-0.35, 1.05),
          ncol=1, fancybox=True, shadow=True)
#plt.show()
#savefig("/home/muhammad/Dropbox/transferReport/tex/diagrams/Cosine.eps")

# %%
import matplotlib.pyplot as plt
plt.subplot2grid((3,3), (1,0), rowspan=2)

ker1 = GPy.kern.Cosine(input_dim=1, variance = .7, lengthscale=0.5)
ker2 = GPy.kern.Cosine(input_dim=1, variance = 0.5, lengthscale=2.)
ker3 = GPy.kern.Cosine(input_dim=1, variance = 0.2, lengthscale=1.)
ker1.plot()
ker2.plot()
ker3.plot()
plt.title('(a) Kernels')


plt.subplot2grid((3,3), (0,1), colspan=2, rowspan=3)
#k1 = GPy.kern.RBF(1,.1,1)
#k1 = GPy.kern.RBF(1,variance=.1, lengthscale=1.)

# Simulate sample paths
X = np.linspace(-10,10,501)[:,None]

#ax = plt.subplot(111)savefig("/home/muhammad/Dropbox/transferReport/tex/diagrams/Mat32_edit_cov.eps")
Y = np.random.multivariate_normal(np.zeros(501),ker1.K(X),1)
plt.plot(X,Y[0,:], label= '$l=0.5; a=0.7$')
Y = np.random.multivariate_normal(np.zeros(501),ker2.K(X),1)
plt.plot(X,Y[0,:], label= '$l=2.0; a=0.5$')
Y = np.random.multivariate_normal(np.zeros(501),ker3.K(X),1)
plt.plot(X,Y[0,:], label= '$l=1.0; a=0.2$')
#plt.ylim([-1.2,1.2])
plt.title('(b) Sample functions')
#ax.legend(loc='upper center', bbox_to_anchor=(0.5, 1.05),
#          ncol=1, fancybox=True, shadow=True)

legend(loc='upper center', bbox_to_anchor=(-0.35, 1.05),
          ncol=1, fancybox=True, shadow=True)
#plt.show()
#savefig("/home/muhammad/Dropbox/transferReport/tex/diagrams/Mat32_edit_cov.eps")

# %%
X = np.linspace(-10,10,501)[:,None]

# %%
ker1 = GPy.kern.Matern52(input_dim=1, variance = .7, lengthscale=0.5)
ker2 = GPy.kern.Matern52(input_dim=1, variance = 0.5, lengthscale=2.)
ker3 = GPy.kern.Matern52(input_dim=1, variance = 0.2, lengthscale=1.)

# %%
C = ker2.K(X,X)
pb.matshow(C)

# %%
ker1 = GPy.kern.Linear(input_dim=1, variances = .7, ARD = 'True')
C = ker2.K(X,X)
pb.matshow(C)

# %%
GPy.kern.Linear?

# %%
Y = np.random.multivariate_normal(np.zeros(501),ker1.K(X),1)
plt.plot(X,Y[0,:], label= '$l=1.0; a=0.2$')

# %%
ker1.plot()

# %%
import GPy
import numpy as np
import pylab as pb
import matplotlib.pyplot as plt
pb.ion()
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
X = np.linspace(10,15,20)[:,None]
#print X
#X_star = np.linspace(10,20,51)[:,None]
X_pred = np.linspace(8,20,80)[:,None]
#x_pred = linspace(0, 4, num_pred_data)[:, None]
#print X_pred

# %%
ker1 = GPy.kern.RBF(input_dim=1, variance = .7, lengthscale=0.5)
ker2 = GPy.kern.RBF(input_dim=1, variance = 0.5, lengthscale=2.)
ker3 = GPy.kern.RBF(input_dim=1, variance = 0.2, lengthscale=1.)

# %%
K = ker2.K(X,X)
pb.matshow(C)

# %%
K_star = ker2.K(X,X_pred)
pb.matshow(C.T)

# %%
K = ker2.K(X,X)
K_star = ker2.K(X,X_pred)
K_starstar = ker2.K(X_pred,X_pred)
full_K = np.vstack([np.hstack([K, K_star]), np.hstack([K_star.T, K_starstar])])
plt.imshow(full_K)
plt.colorbar
# Out:
# <function matplotlib.pyplot.colorbar>

# %%
import GPy
import numpy as np
import pylab as pb
import matplotlib.pyplot as plt
plt.close()

pb.ion()
# %pylab inline

X = np.linspace(10,15,18)[:,None]
#print X
#X_star = np.linspace(10,20,51)[:,None]
X_pred = np.linspace(8,20,82)[:,None]
#x_pred = linspace(0, 4, num_pred_data)[:, None]
#print X_pred

ker1 = GPy.kern.OU(input_dim=1, variance = .7, lengthscale=0.5)
ker2 = GPy.kern.OU(input_dim=1, variance = 0.5, lengthscale=1.8)
ker3 = GPy.kern.RBF(input_dim=1, variance = 0.2, lengthscale=1.)

ker = ker2

K = ker.K(X,X)
K_star = ker.K(X,X_pred)
K_starstar = ker.K(X_pred,X_pred)
full_K = np.vstack([np.hstack([K, K_star]), np.hstack([K_star.T, K_starstar])])
plt.imshow(full_K)
plt.colorbar()
plt.show()
#pb.savefig("/home/muhammad/Dropbox/transferReport/tex/diagrams/Cov_Structure.eps")
#pb.savefig("Cov_Structure.eps")
# Out:
# Populating the interactive namespace from numpy and matplotlib
